# %%
import os
import os.path as osp
import copy as cp
import tempfile
import time

import cv2
import mmcv
import mmengine
import numpy as np
import torch

# %%
cap = cv2.VideoCapture(0)
print(f'kamera terbuka: {cap.isOpened()}')
print(f'resolusi kamera: {cap.get(cv2.CAP_PROP_FRAME_WIDTH)}x{cap.get(cv2.CAP_PROP_FRAME_HEIGHT)}')
ret, frame = cap.read()
print(f'frame terbaca: {ret}')
if ret:
    print(f'ukuran frame: {frame.shape}')
else:
    print('gagal membaca frame')
cap.release()
# Out:
# kamera terbuka: True
# resolusi kamera: 640.0x480.0
# frame terbaca: True
# ukuran frame: (480, 640, 3)
